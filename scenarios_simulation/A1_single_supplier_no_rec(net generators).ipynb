# %% [markdown]
# # Scenario A1: Single Supplier — No REC (Net Generators)
#
# **Description:** Baseline scenario. Single supplier mandate where all consumers and
# prosumers use ONE supplier (SUP_A / BG_A). No Renewable Energy Community structure.
# Prosumers are modelled as **net generators** — only their RES output is billed;
# local prosumer loads are excluded from settlement.
#
# **Configuration:**
# | Parameter | Value |
# |---|---|
# | Suppliers | 1 — SUP_A |
# | Balancing Groups | 1 — BG_A (all 9 participants) |
# | RECs | None |
# | Prosumer type | **Net generator** (RES only, no local load) |
# | Battery | None |
#
# **Research role:** Pure baseline for the net-generator track. All subsequent
# net-generator scenarios are compared against A1 to quantify the incremental effect
# of RECs, multiple suppliers, and forecast scheduling.
#
# **Comparison pairs (net-generator track):**
# - A1 vs A2 → value of adding a REC under single-supplier mandate
# - A1 vs B1 → effect of introducing a second independent supplier
# - A1 vs B2 → combined effect of multi-supplier + REC

# %% [markdown]
# ## 1. Import Dependencies
# Import the EnergyMarketOperations class which handles the complete market simulation pipeline.

# %%
from energy_market_operations import EnergyMarketOperations

# %% [markdown]
# ## 2. Initialize Pipeline
# Load the scenario configuration from JSON and create the pipeline instance. The config specifies participants, suppliers, market prices, and network topology.

# %%
CONFIG_FILE = "A1_single_supplier_no_rec(net generators).json"
pipe = EnergyMarketOperations(CONFIG_FILE, scenario_name="A1 Single Supplier No REC (Net Generators)")

# %% [markdown]
# ## 3. Run Full Pipeline
# Execute the complete market simulation:
# 1. **Day-Ahead Market** - Schedule energy positions based on DA forecasts
# 2. **Intra-Day Market** - Adjust positions with updated ID forecasts
# 3. **REC Settlement** - (Skipped for A1 - no REC configured)
# 4. **Balancing Market** - Settle imbalances at dual pricing
# 5. **Supplier Billing** - Calculate final costs per participant

# %%
pipe.run_all()
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Running full pipeline for: A1 Single Supplier No REC (Net Generators)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# ================================================================================
#   SCENARIO: A1 Single Supplier No REC (Net Generators)
# ================================================================================
#   System  : Single Supplier Mandate without REC - Scenario A1
#   Period  : 2016-01-01 → 2016-12-31
#   Suppliers    : 1
#   Prosumers    : 3
#   Consumers    : 6
#   RECs         : 0  →  has_rec = False
#   Battery      : False
# ================================================================================
# ✓ Prices loaded: (35136, 5)  from prices.csv
# ✓ Load actual : (35136, 153)
# ✓ RES actual  : (35136, 27)
# ✓ Load forecast DA: (35136, 6)
# ✓ RES  forecast DA: (35136, 3)
# ✓ Load forecast ID: (35136, 6)
# ✓ RES  forecast ID: (35136, 3)
# ✓ DA market: (35136, 8)
# ✓ ID market : (35136, 19)
# ⚠ Battery optimization: skipped (no battery in config)
# ✓ REC settlement: SKIPPED (no RECs in config)
# ✓ Balancing market: (35136, 27)
# ✓ Customer billing: (316224, 12)  (9 customers)
# ✓ Monthly aggregation: (12, 26)
# ✓ Profit/loss calculated
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Pipeline complete: A1 Single Supplier No REC (Net Generators)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %% [markdown]
# ## 4. Financial Summary
# Display aggregated financial results including total revenues, costs, and profit/loss for the supplier.

# %%
pipe.summary()
# Out:
# ================================================================================
#   ANNUAL FINANCIAL SUMMARY – A1 SINGLE SUPPLIER NO REC (NET GENERATORS)
# ================================================================================
#
#   SUP_A (Supplier A):
#
#     REVENUES:
#       Energy Market Sales : €      283.12
#       Balancing Rewards   : €       71.15
#       Retail Sales        : €   29,814.30
#       ────────────────────────────────────────────
#       Total Revenue       : €   30,168.57
#
#     COSTS:
#       Market Purchases    : €    3,463.56
#       Balancing Penalties  : €       70.57
#       Retail Purchases     : €    4,670.08
#       ────────────────────────────────────────────
#       Total Costs          : €    8,204.21
#
#     PROFIT/LOSS:
#       Annual Total         : €   21,964.36
#       Monthly Average      : €    1,830.36
#
#     IMBALANCE:
#       System Position      : SHORT
#       Total Imbalance      :         0.01 MWh
#       BG Actual Position   :        91.65 MWh
#       BG Forecast Position :        91.65 MWh
#
# ================================================================================

# %% [markdown]
# ## 5. Financial Visualization
# Plot breakdown of revenues and costs by category (DA purchases, ID adjustments, balancing costs, customer sales).

# %%
pipe.plot_financials()

# %% [markdown]
# ## 6. Imbalance Analysis
# Visualize system imbalances over time showing the difference between scheduled positions and actual metered values.

# %%
pipe.plot_imbalances()

# %% [markdown]
# ## 7. Monthly Analysis Data
# Display the detailed monthly analysis DataFrame with all financial metrics broken down by month.

# %%
pipe.es_monthly_analysis_df
# Out:
#    datetime supplier_id balancing_group_id  da_net_load_forecast_mwh  \
# 0   01-2016       SUP_A               BG_A                 11.740290
# 1   02-2016       SUP_A               BG_A                 12.437626
# 2   03-2016       SUP_A               BG_A                 10.352735
# 3   04-2016       SUP_A               BG_A                  8.797402
# 4   05-2016       SUP_A               BG_A                  6.573481
# 5   06-2016       SUP_A               BG_A                  8.714424
# 6   07-2016       SUP_A               BG_A                  8.391116
# 7   08-2016       SUP_A               BG_A                  4.780504
# 8   09-2016       SUP_A               BG_A                  9.887178
# 9   10-2016       SUP_A               BG_A                 10.156405
# 10  11-2016       SUP_A               BG_A                 12.671885
# 11  12-2016       SUP_A               BG_A                 13.928092
#
#     da_net_gen_forecast_mwh  da_purchase_commitment_eur  \
# 0                  0.180791                  395.381203
# 1                  0.121162                  314.480153
# 2                  1.026866                  274.725242
# 3                  1.032603                  241.398511
# 4                  2.838498                  173.232440
# 5                  1.064149                  260.907549
# 6                  1.604744                  247.727572
# 7                  2.522270                  142.692441
# 8                  0.704498                  316.982297
# 9                  0.581479                  398.922563
# 10                 0.216691                  550.727848
# 11                 0.050796                  581.829721
#
#     da_sale_commitment_eur  id_net_load_adjustment_mwh  \
# 0                 4.664840                   -1.175045
# 1                 1.882415                   -1.345223
# 2                15.168111                   -1.208871
# 3                19.683030                   -1.127719
# 4                44.972758                   -0.817546
# 5                21.989673                   -1.039799
# 6                31.466332                   -1.056170
# 7                58.390462                   -0.596044
# 8                17.102633                   -1.173166
# 9                19.880555                   -1.103117
# 10                5.976360                   -1.305366
# 11                1.916624                   -1.353119
#
#     id_net_gen_adjustment_mwh  id_price_eur_per_mwh  ...  purchase_costs_eur  \
# 0                    0.030932             29.579375  ...          134.072290
# 1                    0.021096             22.463459  ...          224.344400
# 2                    0.091983             24.094009  ...          423.944189
# 3                    0.173916             25.257687  ...          528.246823
# 4                    0.292393             22.993579  ...          670.711583
# 5                    0.152722             27.651608  ...          466.291262
# 6                    0.221446             27.138380  ...          589.929932
# 7                    0.295230             27.268374  ...          612.143347
# 8                    0.121973             30.137590  ...          435.577534
# 9                    0.095788             36.908256  ...          291.957965
# 10                   0.025765             39.158729  ...          187.481974
# 11                   0.015506             37.726559  ...          105.377882
#
#     revenue_energy_market_sales_eur  revenue_balancing_rewards_eur  \
# 0                          5.529485                       4.009907
# 1                          2.230811                       4.371368
# 2                         17.181040                       5.183383
# 3                         23.901538                       5.622824
# 4                         51.825879                       9.036340
# 5                         25.999581                       6.102997
# 6                         37.108990                       7.205016
# 7                         66.161635                       7.847995
# 8                         20.628851                       7.436418
# 9                         23.348741                       6.078231
# 10                         6.690527                       4.550514
# 11                         2.509790                       3.707046
#
#     revenue_retail_sales_eur  total_revenue_eur  \
# 0                2409.099920        2418.639312
# 1                2747.154187        2753.756366
# 2                2645.394321        2667.758744
# 3                2591.454116        2620.978478
# 4                2168.971492        2229.833712
# 5                2432.454674        2464.557252
# 6                2547.834860        2592.148866
# 7                1768.591202        1842.600832
# 8                2645.740784        2673.806054
# 9                2396.744228        2426.171200
# 10               2690.723907        2701.964948
# 11               2770.136732        2776.353569
#
#     cost_energy_market_purchases_eur  cost_balancing_penalties_eur  \
# 0                         355.532769                      3.465164
# 1                         280.228549                      4.270064
# 2                         242.508724                      7.437098
# 3                         210.669928                      4.842401
# 4                         151.316925                      6.396274
# 5                         229.172007                      5.689004
# 6                         216.402585                      7.160590
# 7                         124.678803                      8.750842
# 8                         279.304556                      7.860264
# 9                         354.876465                      6.015983
# 10                        493.851281                      4.736223
# 11                        525.016993                      3.950851
#
#     cost_retail_purchases_eur  total_costs_eur  profit_loss_eur
# 0                  134.072290       493.070224      1925.569088
# 1                  224.344400       508.843013      2244.913353
# 2                  423.944189       673.890011      1993.868733
# 3                  528.246823       743.759152      1877.219326
# 4                  670.711583       828.424782      1401.408930
# 5                  466.291262       701.152272      1763.404979
# 6                  589.929932       813.493108      1778.655759
# 7                  612.143347       745.572992      1097.027840
# 8                  435.577534       722.742354      1951.063699
# 9                  291.957965       652.850412      1773.320788
# 10                 187.481974       686.069478      2015.895471
# 11                 105.377882       634.345727      2142.007842
#
# [12 rows x 35 columns]

# %% [markdown]
# ## 8. Customer Billing Summary
# Display aggregated customer billing by customer type (consumer/prosumer).

# %%
pipe.customer_billing_df.groupby('customer_type').agg({
    'sales_revenue_eur': 'sum',
    'purchase_costs_eur': 'sum',
    'actual_load_mwh': 'sum',
    'actual_gen_mwh': 'sum'
})
# Out:
#                sales_revenue_eur  purchase_costs_eur  actual_load_mwh  \
# customer_type
# consumer            29814.300424            0.000000       148.329853
# prosumer                0.000000         4670.079182         0.000000
#
#                actual_gen_mwh
# customer_type
# consumer             0.000000
# prosumer            56.675718
